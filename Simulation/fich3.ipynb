# %%
import numpy as np
import matplotlib.pyplot as plt
import math

fig = plt.figure(figsize=(8,8))
data = np.loadtxt('./fich3.txt')
X = data[:,0]
Y = data[:,1]
plt.scatter(X,Y)
plt.title('Brownian motion 2D à t=100',fontweight = 'bold')
plt.show()
