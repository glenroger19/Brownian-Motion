# %%
import numpy as np
import matplotlib.pyplot as plt
import math

data = np.loadtxt('./brownian.txt')
T = data[:,0]
X = data[:,1]
plt.plot(T,X);
##title('Mouvement brownien 1D (sigma^2 = 2)');
plt.show()
