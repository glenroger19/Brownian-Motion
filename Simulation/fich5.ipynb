# %%
import numpy as np
import matplotlib.pyplot as plt
import math

fig = plt.figure(figsize=(8,8))
data = np.loadtxt('./fich5.txt')
X = data[:,0]
Y = data[:,1]
plt.plot(X,Y)
plt.title('Brownian motion 2D',fontweight = 'bold')
plt.show()
