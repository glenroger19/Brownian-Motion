# %%
import numpy as np
import matplotlib.pyplot as plt
import math

data = np.loadtxt('./brownian1D.txt')
T = data[:,0]
X = data[:,1]
plt.plot(T,X)
plt.title('Brownian motion 1D',fontweight = 'bold',color = 'red')
plt.show()
