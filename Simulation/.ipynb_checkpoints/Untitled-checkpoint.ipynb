# %%
import numpy as np
import matplotlib.pyplot as plt
import math

fig = plt.figure(figsize=(8,8))
data = np.loadtxt('./echappement.txt')
data1 = np.loadtxt('./echappement1.txt')
data2 = np.loadtxt('./echappement2.txt')
plt.plot(data[:,0],data[:,1],color='r')
##plt.plot(data[:,0],data1[:,1],color='b')
##plt.plot(data[:,0],data2[:,1],color='k')
plt.show()
